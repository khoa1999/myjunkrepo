# %%
! pip install tensorflow==2.14.0
! pip install tensorflow_text==2.14.0
! pip install tensorflow-datasets==4.9.2
! pip install numpy==1.23.5
! pip install torch==2.0.1
! pip install torchvision==0.15.2
! pip install opencv-python==4.7.0.72
! pip install tqdm==4.65.0
! pip install git+https://github.com/openai/CLIP.git@a1d071733d7111c9c014f024669f959182114e33
! pip install Pillow==9.1.1
! pip install orbax-checkpoint==0.3.3
! pip install gin-config==0.5.0
! pip install pycocotools==2.0.6
! pip install contextlib2==21.6.0
! pip install ml-collections==0.1.1
! pip install chex==0.1.7
! pip install optax==0.1.5
! pip install --no-deps flax==0.7.2
! pip install --no-deps clu==0.0.9
! pip install jax==0.4.9 
! pip install Cython==3.0.0
! pip install git+https://github.com/cocodataset/cocoapi@8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9#subdirectory=PythonAPI
# Out:
# Collecting tensorflow==2.14.0
#   Downloading tensorflow-2.14.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting tensorflow-macos==2.14.0 (from tensorflow==2.14.0)
#   Downloading tensorflow_macos-2.14.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.9 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Requirement already satisfied: h5py>=2.9.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow==2.14.0) (3.9.0)
# Collecting libclang>=13.0.0 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting ml-dtypes==0.2.0 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading ml_dtypes-0.2.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.23.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow==2.14.0) (1.24.3)
# Collecting opt-einsum>=2.3.2 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow==2.14.0) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow==2.14.0) (4.25.3)
# Requirement already satisfied: setuptools in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow==2.14.0) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow==2.14.0) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow==2.14.0) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow==2.14.0) (1.14.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow==2.14.0) (1.62.1)
# Collecting tensorboard<2.15,>=2.14 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading tensorboard-2.14.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.15,>=2.14.0 (from tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading keras-2.14.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.14.0->tensorflow==2.14.0) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (2.29.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (2.31.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (4.9)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0) (0.4.8)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow==2.14.0)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading tensorflow-2.14.0-cp311-cp311-macosx_12_0_arm64.whl (2.1 kB)
# Downloading tensorflow_macos-2.14.0-cp311-cp311-macosx_12_0_arm64.whl (199.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 MB 1.3 MB/s eta 0:00:0000:0100:04
# Downloading ml_dtypes-0.2.0-cp311-cp311-macosx_10_9_universal2.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.6 MB/s eta 0:00:00a 0:00:01
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 5.7 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.4 MB/s eta 0:00:00
# Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 7.2 MB/s eta 0:00:0000:0100:01
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.4 MB/s eta 0:00:00
# Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 8.3 MB/s eta 0:00:0000:0100:01m
# Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 8.0 MB/s eta 0:00:00ta 0:00:01
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_12_0_arm64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 9.4 MB/s eta 0:00:0000:0100:01m
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 17.1 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, opt-einsum, oauthlib, ml-dtypes, keras, google-pasta, gast, astunparse, absl-py, requests-oauthlib, google-auth-oauthlib, tensorboard, tensorflow-macos, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.6.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 keras-2.14.0 libclang-18.1.1 ml-dtypes-0.2.0 oauthlib-3.2.2 opt-einsum-3.3.0 requests-oauthlib-2.0.0 tensorboard-2.14.1 tensorboard-data-server-0.7.2 tensorflow-2.14.0 tensorflow-estimator-2.14.0 tensorflow-io-gcs-filesystem-0.37.1 tensorflow-macos-2.14.0 termcolor-2.4.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement tensorflow_text==2.14.0 (from versions: 2.17.0rc0)
# ERROR: No matching distribution found for tensorflow_text==2.14.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting tensorflow-datasets==4.9.2
#   Downloading tensorflow_datasets-4.9.2-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: absl-py in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (2.1.0)
# Collecting array-record (from tensorflow-datasets==4.9.2)
#   Downloading array_record-0.4.1-py310-none-any.whl.metadata (503 bytes)
# Requirement already satisfied: click in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (8.0.4)
# Collecting dm-tree (from tensorflow-datasets==4.9.2)
#   Downloading dm_tree-0.1.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.9 kB)
# Collecting etils>=0.9.0 (from etils[enp,epath]>=0.9.0->tensorflow-datasets==4.9.2)
#   Downloading etils-1.9.2-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (1.24.3)
# Collecting promise (from tensorflow-datasets==4.9.2)
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf>=3.20 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (4.25.3)
# Requirement already satisfied: psutil in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (5.9.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (2.31.0)
# Collecting tensorflow-metadata (from tensorflow-datasets==4.9.2)
#   Downloading tensorflow_metadata-1.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: termcolor in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (2.4.0)
# Requirement already satisfied: toml in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (0.10.2)
# Requirement already satisfied: tqdm in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (4.65.0)
# Requirement already satisfied: wrapt in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets==4.9.2) (1.14.1)
# Requirement already satisfied: fsspec in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets==4.9.2) (2023.4.0)
# Collecting importlib_resources (from etils[enp,epath]>=0.9.0->tensorflow-datasets==4.9.2)
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing_extensions in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets==4.9.2) (4.12.2)
# Requirement already satisfied: zipp in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets==4.9.2) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets==4.9.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets==4.9.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets==4.9.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets==4.9.2) (2024.6.2)
# Requirement already satisfied: six in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from promise->tensorflow-datasets==4.9.2) (1.16.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from tensorflow-metadata->tensorflow-datasets==4.9.2) (1.63.0)
# Downloading tensorflow_datasets-4.9.2-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 17.1 MB/s eta 0:00:00a 0:00:01
# Downloading etils-1.9.2-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 17.1 MB/s eta 0:00:00
# Downloading array_record-0.4.1-py310-none-any.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 2.1 MB/s eta 0:00:0000:0100:010m
# Downloading dm_tree-0.1.8-cp311-cp311-macosx_11_0_arm64.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 13.0 MB/s eta 0:00:00
# Downloading tensorflow_metadata-1.15.0-py3-none-any.whl (28 kB)
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Building wheels for collected packages: promise
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21486 sha256=6a1854b562556e76e34290d9a37302cfd8c059804e1fbd676b3d257d8e7d83b1
#   Stored in directory: /Users/dangkhoa/Library/Caches/pip/wheels/90/74/b1/9b54c896b8d9409e9268329d4d45ede8a8040abe91c8879932
# Successfully built promise
# Installing collected packages: dm-tree, promise, importlib_resources, etils, tensorflow-metadata, array-record, tensorflow-datasets
# Successfully installed array-record-0.4.1 dm-tree-0.1.8 etils-1.9.2 importlib_resources-6.4.0 promise-2.3 tensorflow-datasets-4.9.2 tensorflow-metadata-1.15.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Downloading numpy-1.23.5-cp311-cp311-macosx_11_0_arm64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 53.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# Successfully installed numpy-1.23.5
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting torch==2.0.1
#   Downloading torch-2.0.1-cp311-none-macosx_11_0_arm64.whl.metadata (23 kB)
# Requirement already satisfied: filelock in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1) (3.14.0)
# Requirement already satisfied: typing-extensions in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1) (4.12.2)
# Requirement already satisfied: sympy in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1) (1.11.1)
# Requirement already satisfied: networkx in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1) (3.1)
# Requirement already satisfied: jinja2 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jinja2->torch==2.0.1) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from sympy->torch==2.0.1) (1.3.0)
# Downloading torch-2.0.1-cp311-none-macosx_11_0_arm64.whl (55.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 MB 37.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1
#     Uninstalling torch-2.2.1:
#       Successfully uninstalled torch-2.2.1
# Successfully installed torch-2.0.1
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting torchvision==0.15.2
#   Downloading torchvision-0.15.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torchvision==0.15.2) (1.23.5)
# Requirement already satisfied: requests in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torchvision==0.15.2) (2.31.0)
# Requirement already satisfied: torch==2.0.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torchvision==0.15.2) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torchvision==0.15.2) (10.3.0)
# Requirement already satisfied: filelock in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1->torchvision==0.15.2) (3.14.0)
# Requirement already satisfied: typing-extensions in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1->torchvision==0.15.2) (4.12.2)
# Requirement already satisfied: sympy in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1->torchvision==0.15.2) (1.11.1)
# Requirement already satisfied: networkx in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1->torchvision==0.15.2) (3.1)
# Requirement already satisfied: jinja2 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch==2.0.1->torchvision==0.15.2) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests->torchvision==0.15.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests->torchvision==0.15.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests->torchvision==0.15.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests->torchvision==0.15.2) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jinja2->torch==2.0.1->torchvision==0.15.2) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from sympy->torch==2.0.1->torchvision==0.15.2) (1.3.0)
# Downloading torchvision-0.15.2-cp311-cp311-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 6.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.17.1
#     Uninstalling torchvision-0.17.1:
#       Successfully uninstalled torchvision-0.17.1
# Successfully installed torchvision-0.15.2
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting opencv-python==4.7.0.72
#   Downloading opencv_python-4.7.0.72-cp37-abi3-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from opencv-python==4.7.0.72) (1.23.5)
# Downloading opencv_python-4.7.0.72-cp37-abi3-macosx_11_0_arm64.whl (32.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.6/32.6 MB 6.7 MB/s eta 0:00:0000:01m00:01
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
# Successfully installed opencv-python-4.7.0.72
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tqdm==4.65.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (4.65.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting git+https://github.com/openai/CLIP.git@a1d071733d7111c9c014f024669f959182114e33
#   Cloning https://github.com/openai/CLIP.git (to revision a1d071733d7111c9c014f024669f959182114e33) to /private/var/folders/fr/mq_5f6n53t95jwp746gcqjnr0000gn/T/pip-req-build-8o1kcqrk
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /private/var/folders/fr/mq_5f6n53t95jwp746gcqjnr0000gn/T/pip-req-build-8o1kcqrk
#   Running command git rev-parse -q --verify 'sha^a1d071733d7111c9c014f024669f959182114e33'
#   Running command git fetch -q https://github.com/openai/CLIP.git a1d071733d7111c9c014f024669f959182114e33
#   Running command git checkout -q a1d071733d7111c9c014f024669f959182114e33
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from clip==1.0) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from clip==1.0) (4.65.0)
# Requirement already satisfied: torch in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from clip==1.0) (2.0.1)
# Requirement already satisfied: torchvision in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from clip==1.0) (0.15.2)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy->clip==1.0)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (3.14.0)
# Requirement already satisfied: typing-extensions in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: sympy in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (1.11.1)
# Requirement already satisfied: networkx in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (3.1)
# Requirement already satisfied: jinja2 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: numpy in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torchvision->clip==1.0) (1.23.5)
# Requirement already satisfied: requests in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torchvision->clip==1.0) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from torchvision->clip==1.0) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jinja2->torch->clip==1.0) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (2024.6.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from sympy->torch->clip==1.0) (1.3.0)
# Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 980.8 kB/s eta 0:00:000:00:01
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369497 sha256=aed545d067c4285ce8c01ce38bda25d264e5fe0478739b5913267c908c109787
#   Stored in directory: /Users/dangkhoa/Library/Caches/pip/wheels/4a/d6/f2/bed45f97d621496d23b0097b67ce80e41b4382c28d60ecadb5
# Successfully built clip
# Installing collected packages: wcwidth, ftfy, clip
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Successfully uninstalled wcwidth-0.2.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.3 requires pyqt5<5.16, which is not installed.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# Successfully installed clip-1.0 ftfy-6.2.0 wcwidth-0.2.13
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting Pillow==9.1.1
#   Downloading Pillow-9.1.1.tar.gz (49.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 MB 24.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: Pillow
#   Building wheel for Pillow (setup.py) ... done
#   Created wheel for Pillow: filename=Pillow-9.1.1-cp311-cp311-macosx_11_0_arm64.whl size=546375 sha256=61a489bcc7aba2e2ab12d52c489b8132c3e800916813ab12466c2b43097f8d8b
#   Stored in directory: /Users/dangkhoa/Library/Caches/pip/wheels/e2/4b/db/138649a9bc3b3fce03b5a7154bd69f50d28f1d46c80a3904b0
# Successfully built Pillow
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 10.3.0
#     Uninstalling pillow-10.3.0:
#       Successfully uninstalled pillow-10.3.0
# Successfully installed Pillow-9.1.1
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting orbax-checkpoint==0.3.3
#   Downloading orbax_checkpoint-0.3.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: absl-py in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from orbax-checkpoint==0.3.3) (2.1.0)
# Requirement already satisfied: etils[epath,epy] in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from orbax-checkpoint==0.3.3) (1.9.2)
# Requirement already satisfied: typing_extensions in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from orbax-checkpoint==0.3.3) (4.12.2)
# Requirement already satisfied: msgpack in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from orbax-checkpoint==0.3.3) (1.0.3)
# Collecting jax>=0.4.9 (from orbax-checkpoint==0.3.3)
#   Downloading jax-0.4.30-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib (from orbax-checkpoint==0.3.3)
#   Downloading jaxlib-0.4.30-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from orbax-checkpoint==0.3.3) (1.23.5)
# Requirement already satisfied: pyyaml in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from orbax-checkpoint==0.3.3) (6.0)
# Collecting tensorstore>=0.1.35 (from orbax-checkpoint==0.3.3)
#   Downloading tensorstore-0.1.63-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Requirement already satisfied: nest_asyncio in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from orbax-checkpoint==0.3.3) (1.5.6)
# Requirement already satisfied: protobuf in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from orbax-checkpoint==0.3.3) (4.25.3)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax>=0.4.9->orbax-checkpoint==0.3.3) (0.2.0)
# Requirement already satisfied: opt-einsum in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax>=0.4.9->orbax-checkpoint==0.3.3) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax>=0.4.9->orbax-checkpoint==0.3.3) (1.11.1)
# Collecting ml-dtypes>=0.2.0 (from jax>=0.4.9->orbax-checkpoint==0.3.3)
#   Downloading ml_dtypes-0.4.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: fsspec in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from etils[epath,epy]->orbax-checkpoint==0.3.3) (2023.4.0)
# Requirement already satisfied: importlib_resources in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from etils[epath,epy]->orbax-checkpoint==0.3.3) (6.4.0)
# Requirement already satisfied: zipp in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from etils[epath,epy]->orbax-checkpoint==0.3.3) (3.11.0)
# Downloading orbax_checkpoint-0.3.3-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading jax-0.4.30-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.3 MB/s eta 0:00:00 0:00:01
# Downloading jaxlib-0.4.30-cp311-cp311-macosx_11_0_arm64.whl (66.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 MB 15.5 MB/s eta 0:00:0000:0100:01
# Downloading tensorstore-0.1.63-cp311-cp311-macosx_11_0_arm64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 13.3 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.4.0-cp311-cp311-macosx_10_9_universal2.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 11.2 MB/s eta 0:00:00
# Installing collected packages: ml-dtypes, tensorstore, jaxlib, jax, orbax-checkpoint
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.14.0 requires ml-dtypes==0.2.0, but you have ml-dtypes 0.4.0 which is incompatible.
# Successfully installed jax-0.4.30 jaxlib-0.4.30 ml-dtypes-0.4.0 orbax-checkpoint-0.3.3 tensorstore-0.1.63
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting gin-config==0.5.0
#   Downloading gin_config-0.5.0-py3-none-any.whl.metadata (2.9 kB)
# Downloading gin_config-0.5.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 695.1 kB/s eta 0:00:000:00:01
# Installing collected packages: gin-config
# Successfully installed gin-config-0.5.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting pycocotools==2.0.6
#   Downloading pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=2.1.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from pycocotools==2.0.6) (3.7.2)
# Requirement already satisfied: numpy in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from pycocotools==2.0.6) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (9.1.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0.6) (1.16.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp311-cp311-macosx_11_0_arm64.whl size=81880 sha256=f75cabfa24b96c1e46322fd9a8eecb7da903383ea467bf16de7c0c830a013626
#   Stored in directory: /Users/dangkhoa/Library/Caches/pip/wheels/ad/ca/ea/fb115e04c841c3f71fd369b7d9805a43a5193f4f9251bed0ec
# Successfully built pycocotools
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.6
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting contextlib2==21.6.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Installing collected packages: contextlib2
# Successfully installed contextlib2-21.6.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting ml-collections==0.1.1
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 1.2 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from ml-collections==0.1.1) (2.1.0)
# Requirement already satisfied: PyYAML in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from ml-collections==0.1.1) (6.0)
# Requirement already satisfied: six in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from ml-collections==0.1.1) (1.16.0)
# Requirement already satisfied: contextlib2 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from ml-collections==0.1.1) (21.6.0)
# Building wheels for collected packages: ml-collections
#   Building wheel for ml-collections (setup.py) ... done
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94506 sha256=577785e5d39b3f00711fdeb3fbb5eb5c6c2ffb1d7783359ee65e32b139132fdc
#   Stored in directory: /Users/dangkhoa/Library/Caches/pip/wheels/28/82/ef/a6971b09a96519d55ce6efef66f0cbcdef2ae9cc1e6b41daf7
# Successfully built ml-collections
# Installing collected packages: ml-collections
# Successfully installed ml-collections-0.1.1
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting chex==0.1.7
#   Downloading chex-0.1.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: absl-py>=0.9.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from chex==0.1.7) (2.1.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from chex==0.1.7) (0.1.8)
# Requirement already satisfied: jax>=0.4.6 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from chex==0.1.7) (0.4.30)
# Requirement already satisfied: jaxlib>=0.1.37 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from chex==0.1.7) (0.4.30)
# Requirement already satisfied: numpy>=1.18.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from chex==0.1.7) (1.23.5)
# Requirement already satisfied: toolz>=0.9.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from chex==0.1.7) (0.12.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax>=0.4.6->chex==0.1.7) (0.4.0)
# Requirement already satisfied: opt-einsum in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax>=0.4.6->chex==0.1.7) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax>=0.4.6->chex==0.1.7) (1.11.1)
# Downloading chex-0.1.7-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.6/89.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: chex
# Successfully installed chex-0.1.7
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting optax==0.1.5
#   Downloading optax-0.1.5-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: absl-py>=0.7.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from optax==0.1.5) (2.1.0)
# Requirement already satisfied: chex>=0.1.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from optax==0.1.5) (0.1.7)
# Requirement already satisfied: jax>=0.1.55 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from optax==0.1.5) (0.4.30)
# Requirement already satisfied: jaxlib>=0.1.37 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from optax==0.1.5) (0.4.30)
# Requirement already satisfied: numpy>=1.18.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from optax==0.1.5) (1.23.5)
# Requirement already satisfied: dm-tree>=0.1.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from chex>=0.1.5->optax==0.1.5) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from chex>=0.1.5->optax==0.1.5) (0.12.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax>=0.1.55->optax==0.1.5) (0.4.0)
# Requirement already satisfied: opt-einsum in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax>=0.1.55->optax==0.1.5) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax>=0.1.55->optax==0.1.5) (1.11.1)
# Downloading optax-0.1.5-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.6/164.6 kB 1.5 MB/s eta 0:00:00a 0:00:01m
# Installing collected packages: optax
# Successfully installed optax-0.1.5
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting flax==0.7.2
#   Downloading flax-0.7.2-py3-none-any.whl.metadata (10.0 kB)
# Downloading flax-0.7.2-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.6/226.6 kB 1.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: flax
# Successfully installed flax-0.7.2
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting clu==0.0.9
#   Downloading clu-0.0.9-py3-none-any.whl.metadata (2.0 kB)
# Downloading clu-0.0.9-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 1.2 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: clu
# Successfully installed clu-0.0.9
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting jax==0.4.9
#   Downloading jax-0.4.9.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.6 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ml-dtypes>=0.1.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax==0.4.9) (0.4.0)
# Requirement already satisfied: numpy>=1.21 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax==0.4.9) (1.23.5)
# Requirement already satisfied: opt-einsum in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax==0.4.9) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from jax==0.4.9) (1.11.1)
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.9-py3-none-any.whl size=1477704 sha256=64bfba8cb38d5e26f594ea82cafb4725bda2025d017f55918219d58401fba4d4
#   Stored in directory: /Users/dangkhoa/Library/Caches/pip/wheels/bf/21/15/15bee0aaea78290b765a80e7f93af06f420f73539ae4941fd7
# Successfully built jax
# Installing collected packages: jax
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.30
#     Uninstalling jax-0.4.30:
#       Successfully uninstalled jax-0.4.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flax 0.7.2 requires rich>=11.1, which is not installed.
# Successfully installed jax-0.4.9
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting Cython==3.0.0
#   Downloading Cython-3.0.0-py2.py3-none-any.whl.metadata (3.1 kB)
# Downloading Cython-3.0.0-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: Cython
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# Successfully installed Cython-3.0.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting git+https://github.com/cocodataset/cocoapi@8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi (to revision 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9) to /private/var/folders/fr/mq_5f6n53t95jwp746gcqjnr0000gn/T/pip-req-build-_5qblhnp
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi /private/var/folders/fr/mq_5f6n53t95jwp746gcqjnr0000gn/T/pip-req-build-_5qblhnp
#   Running command git rev-parse -q --verify 'sha^8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9'
#   Running command git fetch -q https://github.com/cocodataset/cocoapi 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Resolved https://github.com/cocodataset/cocoapi to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=18.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from pycocotools==2.0) (68.0.0)
# Requirement already satisfied: cython>=0.27.3 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from pycocotools==2.0) (3.0.0)
# Requirement already satisfied: matplotlib>=2.1.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from pycocotools==2.0) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (9.1.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/dangkhoa/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.16.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp311-cp311-macosx_11_0_arm64.whl size=81327 sha256=4577c4eb539c29d9c10d262cc8ed8dedc964603d109a7fce1537a3d083e81998
#   Stored in directory: /Users/dangkhoa/Library/Caches/pip/wheels/f2/d2/07/261eb3c65d0c9a000ac4114eb01ae48fcbf9e1b7b52c6abc17
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.6
#     Uninstalling pycocotools-2.0.6:
#       Successfully uninstalled pycocotools-2.0.6
# Successfully installed pycocotools-2.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
PROJECT_ID = "hackerthonvn"
! gcloud config set project {PROJECT_ID}
# Out:
# WARNING: Your active project does not match the quota project in your local Application Default Credentials file. This might result in unexpected quota issues.
#
# To update your Application Default Credentials quota project, use the `gcloud auth application-default set-quota-project` command.
# Updated property [core/project].
#
#
# Updates are available for some Google Cloud CLI components.  To install them,
# please run:
#   $ gcloud components update
